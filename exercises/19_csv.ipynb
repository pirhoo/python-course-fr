# %%
# %load 19_csv.py
import csv

# On ouvre le fichier comme du texte
in_file = open("../goodiebag/unemployment.csv", 'rt')
# On interprête ce fichier comme un CSV
csv_file = csv.DictReader(in_file, delimiter=';')

"""
Tâches: convertissez en décimal les propriétés "unemployment_2009" et "unemployment_2014"
à partir du texte en utilisant la fonction float().
"""

# On parcout le fichier ligne par ligne
for row in csv_file:
    print("Orignal data:")
    print(row)
    # Codez ici!
    print(row)
# Out:
# Orignal data:
# OrderedDict([('municipality', 'Ale'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.9')])
# OrderedDict([('municipality', 'Ale'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.9')])
# Orignal data:
# OrderedDict([('municipality', 'Alingsås'), ('unemployment_2009', '5.7'), ('unemployment_2014', '6')])
# OrderedDict([('municipality', 'Alingsås'), ('unemployment_2009', '5.7'), ('unemployment_2014', '6')])
# Orignal data:
# OrderedDict([('municipality', 'Alvesta'), ('unemployment_2009', '4.7'), ('unemployment_2014', '8.9')])
# OrderedDict([('municipality', 'Alvesta'), ('unemployment_2009', '4.7'), ('unemployment_2014', '8.9')])
# Orignal data:
# OrderedDict([('municipality', 'Aneby'), ('unemployment_2009', '4.9'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Aneby'), ('unemployment_2009', '4.9'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Arboga'), ('unemployment_2009', '6.5'), ('unemployment_2014', '9.4')])
# OrderedDict([('municipality', 'Arboga'), ('unemployment_2009', '6.5'), ('unemployment_2014', '9.4')])
# Orignal data:
# OrderedDict([('municipality', 'Arjeplog'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.6')])
# OrderedDict([('municipality', 'Arjeplog'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.6')])
# Orignal data:
# OrderedDict([('municipality', 'Arvidsjaur'), ('unemployment_2009', '7.8'), ('unemployment_2014', '7.7')])
# OrderedDict([('municipality', 'Arvidsjaur'), ('unemployment_2009', '7.8'), ('unemployment_2014', '7.7')])
# Orignal data:
# OrderedDict([('municipality', 'Arvika'), ('unemployment_2009', '7'), ('unemployment_2014', '6.9')])
# OrderedDict([('municipality', 'Arvika'), ('unemployment_2009', '7'), ('unemployment_2014', '6.9')])
# Orignal data:
# OrderedDict([('municipality', 'Askersund'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Askersund'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Avesta'), ('unemployment_2009', '5.8'), ('unemployment_2014', '8.1')])
# OrderedDict([('municipality', 'Avesta'), ('unemployment_2009', '5.8'), ('unemployment_2014', '8.1')])
# Orignal data:
# OrderedDict([('municipality', 'Bengtsfors'), ('unemployment_2009', '8'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Bengtsfors'), ('unemployment_2009', '8'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Berg'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Berg'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Bjurholm'), ('unemployment_2009', '5.7'), ('unemployment_2014', '9.2')])
# OrderedDict([('municipality', 'Bjurholm'), ('unemployment_2009', '5.7'), ('unemployment_2014', '9.2')])
# Orignal data:
# OrderedDict([('municipality', 'Bjuv'), ('unemployment_2009', '7'), ('unemployment_2014', '8.2')])
# OrderedDict([('municipality', 'Bjuv'), ('unemployment_2009', '7'), ('unemployment_2014', '8.2')])
# Orignal data:
# OrderedDict([('municipality', 'Boden'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Boden'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Bollebygd'), ('unemployment_2009', '5.3'), ('unemployment_2014', '4.4')])
# OrderedDict([('municipality', 'Bollebygd'), ('unemployment_2009', '5.3'), ('unemployment_2014', '4.4')])
# Orignal data:
# OrderedDict([('municipality', 'Bollnäs'), ('unemployment_2009', '8.6'), ('unemployment_2014', '10.4')])
# OrderedDict([('municipality', 'Bollnäs'), ('unemployment_2009', '8.6'), ('unemployment_2014', '10.4')])
# Orignal data:
# OrderedDict([('municipality', 'Borgholm'), ('unemployment_2009', '4.6'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Borgholm'), ('unemployment_2009', '4.6'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Borlänge'), ('unemployment_2009', '6.2'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Borlänge'), ('unemployment_2009', '6.2'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Borås'), ('unemployment_2009', '6.3'), ('unemployment_2014', '6.6')])
# OrderedDict([('municipality', 'Borås'), ('unemployment_2009', '6.3'), ('unemployment_2014', '6.6')])
# Orignal data:
# OrderedDict([('municipality', 'Botkyrka'), ('unemployment_2009', '6.2'), ('unemployment_2014', '9.6')])
# OrderedDict([('municipality', 'Botkyrka'), ('unemployment_2009', '6.2'), ('unemployment_2014', '9.6')])
# Orignal data:
# OrderedDict([('municipality', 'Boxholm'), ('unemployment_2009', '6.1'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Boxholm'), ('unemployment_2009', '6.1'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Bromölla'), ('unemployment_2009', '6.9'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Bromölla'), ('unemployment_2009', '6.9'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Bräcke'), ('unemployment_2009', '9.8'), ('unemployment_2014', '8.4')])
# OrderedDict([('municipality', 'Bräcke'), ('unemployment_2009', '9.8'), ('unemployment_2014', '8.4')])
# Orignal data:
# OrderedDict([('municipality', 'Burlöv'), ('unemployment_2009', '7.1'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Burlöv'), ('unemployment_2009', '7.1'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Båstad'), ('unemployment_2009', '4'), ('unemployment_2014', '6')])
# OrderedDict([('municipality', 'Båstad'), ('unemployment_2009', '4'), ('unemployment_2014', '6')])
# Orignal data:
# OrderedDict([('municipality', 'Dals-Ed'), ('unemployment_2009', '7.3'), ('unemployment_2014', '6.8')])
# OrderedDict([('municipality', 'Dals-Ed'), ('unemployment_2009', '7.3'), ('unemployment_2014', '6.8')])
# Orignal data:
# OrderedDict([('municipality', 'Danderyd'), ('unemployment_2009', '1.6'), ('unemployment_2014', '2')])
# OrderedDict([('municipality', 'Danderyd'), ('unemployment_2009', '1.6'), ('unemployment_2014', '2')])
# Orignal data:
# OrderedDict([('municipality', 'Degerfors'), ('unemployment_2009', '7.2'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Degerfors'), ('unemployment_2009', '7.2'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Dorotea'), ('unemployment_2009', '9'), ('unemployment_2014', '7.6')])
# OrderedDict([('municipality', 'Dorotea'), ('unemployment_2009', '9'), ('unemployment_2014', '7.6')])
# Orignal data:
# OrderedDict([('municipality', 'Eda'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Eda'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Ekerö'), ('unemployment_2009', '1.8'), ('unemployment_2014', '2.7')])
# OrderedDict([('municipality', 'Ekerö'), ('unemployment_2009', '1.8'), ('unemployment_2014', '2.7')])
# Orignal data:
# OrderedDict([('municipality', 'Eksjö'), ('unemployment_2009', '4.5'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Eksjö'), ('unemployment_2009', '4.5'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Emmaboda'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Emmaboda'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Enköping'), ('unemployment_2009', '4.4'), ('unemployment_2014', '4.8')])
# OrderedDict([('municipality', 'Enköping'), ('unemployment_2009', '4.4'), ('unemployment_2014', '4.8')])
# Orignal data:
# OrderedDict([('municipality', 'Eskilstuna'), ('unemployment_2009', '9'), ('unemployment_2014', '11.3')])
# OrderedDict([('municipality', 'Eskilstuna'), ('unemployment_2009', '9'), ('unemployment_2014', '11.3')])
# Orignal data:
# OrderedDict([('municipality', 'Eslöv'), ('unemployment_2009', '4.8'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Eslöv'), ('unemployment_2009', '4.8'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Essunga'), ('unemployment_2009', '5.2'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Essunga'), ('unemployment_2009', '5.2'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Fagersta'), ('unemployment_2009', '6.6'), ('unemployment_2014', '9.7')])
# OrderedDict([('municipality', 'Fagersta'), ('unemployment_2009', '6.6'), ('unemployment_2014', '9.7')])
# Orignal data:
# OrderedDict([('municipality', 'Falkenberg'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Falkenberg'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Falköping'), ('unemployment_2009', '5.8'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Falköping'), ('unemployment_2009', '5.8'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Falun'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Falun'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Filipstad'), ('unemployment_2009', '9.2'), ('unemployment_2014', '9.5')])
# OrderedDict([('municipality', 'Filipstad'), ('unemployment_2009', '9.2'), ('unemployment_2014', '9.5')])
# Orignal data:
# OrderedDict([('municipality', 'Finspång'), ('unemployment_2009', '5.6'), ('unemployment_2014', '9.1')])
# OrderedDict([('municipality', 'Finspång'), ('unemployment_2009', '5.6'), ('unemployment_2014', '9.1')])
# Orignal data:
# OrderedDict([('municipality', 'Flen'), ('unemployment_2009', '7.1'), ('unemployment_2014', '10.4')])
# OrderedDict([('municipality', 'Flen'), ('unemployment_2009', '7.1'), ('unemployment_2014', '10.4')])
# Orignal data:
# OrderedDict([('municipality', 'Forshaga'), ('unemployment_2009', '7.5'), ('unemployment_2014', '8.2')])
# OrderedDict([('municipality', 'Forshaga'), ('unemployment_2009', '7.5'), ('unemployment_2014', '8.2')])
# Orignal data:
# OrderedDict([('municipality', 'Färgelanda'), ('unemployment_2009', '7.7'), ('unemployment_2014', '7')])
# OrderedDict([('municipality', 'Färgelanda'), ('unemployment_2009', '7.7'), ('unemployment_2014', '7')])
# Orignal data:
# OrderedDict([('municipality', 'Gagnef'), ('unemployment_2009', '5.4'), ('unemployment_2014', '4.7')])
# OrderedDict([('municipality', 'Gagnef'), ('unemployment_2009', '5.4'), ('unemployment_2014', '4.7')])
# Orignal data:
# OrderedDict([('municipality', 'Gislaved'), ('unemployment_2009', '6.6'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Gislaved'), ('unemployment_2009', '6.6'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Gnesta'), ('unemployment_2009', '4.1'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Gnesta'), ('unemployment_2009', '4.1'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Gnosjö'), ('unemployment_2009', '7'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Gnosjö'), ('unemployment_2009', '7'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Gotland'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.9')])
# OrderedDict([('municipality', 'Gotland'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.9')])
# Orignal data:
# OrderedDict([('municipality', 'Grums'), ('unemployment_2009', '8.4'), ('unemployment_2014', '8.7')])
# OrderedDict([('municipality', 'Grums'), ('unemployment_2009', '8.4'), ('unemployment_2014', '8.7')])
# Orignal data:
# OrderedDict([('municipality', 'Grästorp'), ('unemployment_2009', '6'), ('unemployment_2014', '6.9')])
# OrderedDict([('municipality', 'Grästorp'), ('unemployment_2009', '6'), ('unemployment_2014', '6.9')])
# Orignal data:
# OrderedDict([('municipality', 'Gullspång'), ('unemployment_2009', '7.3'), ('unemployment_2014', '9.9')])
# OrderedDict([('municipality', 'Gullspång'), ('unemployment_2009', '7.3'), ('unemployment_2014', '9.9')])
# Orignal data:
# OrderedDict([('municipality', 'Gällivare'), ('unemployment_2009', '7.4'), ('unemployment_2014', '6.8')])
# OrderedDict([('municipality', 'Gällivare'), ('unemployment_2009', '7.4'), ('unemployment_2014', '6.8')])
# Orignal data:
# OrderedDict([('municipality', 'Gävle'), ('unemployment_2009', '8.6'), ('unemployment_2014', '10.2')])
# OrderedDict([('municipality', 'Gävle'), ('unemployment_2009', '8.6'), ('unemployment_2014', '10.2')])
# Orignal data:
# OrderedDict([('municipality', 'Göteborg'), ('unemployment_2009', '6.1'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Göteborg'), ('unemployment_2009', '6.1'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Götene'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.3')])
# OrderedDict([('municipality', 'Götene'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.3')])
# Orignal data:
# OrderedDict([('municipality', 'Habo'), ('unemployment_2009', '4.1'), ('unemployment_2014', '3.7')])
# OrderedDict([('municipality', 'Habo'), ('unemployment_2009', '4.1'), ('unemployment_2014', '3.7')])
# Orignal data:
# OrderedDict([('municipality', 'Hagfors'), ('unemployment_2009', '9'), ('unemployment_2014', '9.2')])
# OrderedDict([('municipality', 'Hagfors'), ('unemployment_2009', '9'), ('unemployment_2014', '9.2')])
# Orignal data:
# OrderedDict([('municipality', 'Hallsberg'), ('unemployment_2009', '7.4'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Hallsberg'), ('unemployment_2009', '7.4'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Hallstahammar'), ('unemployment_2009', '7'), ('unemployment_2014', '8.5')])
# OrderedDict([('municipality', 'Hallstahammar'), ('unemployment_2009', '7'), ('unemployment_2014', '8.5')])
# Orignal data:
# OrderedDict([('municipality', 'Halmstad'), ('unemployment_2009', '5.8'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Halmstad'), ('unemployment_2009', '5.8'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Hammarö'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Hammarö'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Haninge'), ('unemployment_2009', '4'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Haninge'), ('unemployment_2009', '4'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Haparanda'), ('unemployment_2009', '15'), ('unemployment_2014', '11.5')])
# OrderedDict([('municipality', 'Haparanda'), ('unemployment_2009', '15'), ('unemployment_2014', '11.5')])
# Orignal data:
# OrderedDict([('municipality', 'Heby'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Heby'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Hedemora'), ('unemployment_2009', '4.9'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Hedemora'), ('unemployment_2009', '4.9'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Helsingborg'), ('unemployment_2009', '6.7'), ('unemployment_2014', '8.5')])
# OrderedDict([('municipality', 'Helsingborg'), ('unemployment_2009', '6.7'), ('unemployment_2014', '8.5')])
# Orignal data:
# OrderedDict([('municipality', 'Herrljunga'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.3')])
# OrderedDict([('municipality', 'Herrljunga'), ('unemployment_2009', '5.9'), ('unemployment_2014', '5.3')])
# Orignal data:
# OrderedDict([('municipality', 'Hjo'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Hjo'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Hofors'), ('unemployment_2009', '7.8'), ('unemployment_2014', '8.1')])
# OrderedDict([('municipality', 'Hofors'), ('unemployment_2009', '7.8'), ('unemployment_2014', '8.1')])
# Orignal data:
# OrderedDict([('municipality', 'Huddinge'), ('unemployment_2009', '4.4'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Huddinge'), ('unemployment_2009', '4.4'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Hudiksvall'), ('unemployment_2009', '7.7'), ('unemployment_2014', '7.9')])
# OrderedDict([('municipality', 'Hudiksvall'), ('unemployment_2009', '7.7'), ('unemployment_2014', '7.9')])
# Orignal data:
# OrderedDict([('municipality', 'Hultsfred'), ('unemployment_2009', '8.3'), ('unemployment_2014', '8.4')])
# OrderedDict([('municipality', 'Hultsfred'), ('unemployment_2009', '8.3'), ('unemployment_2014', '8.4')])
# Orignal data:
# OrderedDict([('municipality', 'Hylte'), ('unemployment_2009', '4.6'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Hylte'), ('unemployment_2009', '4.6'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Håbo'), ('unemployment_2009', '2.7'), ('unemployment_2014', '3.9')])
# OrderedDict([('municipality', 'Håbo'), ('unemployment_2009', '2.7'), ('unemployment_2014', '3.9')])
# Orignal data:
# OrderedDict([('municipality', 'Hällefors'), ('unemployment_2009', '8.9'), ('unemployment_2014', '9.1')])
# OrderedDict([('municipality', 'Hällefors'), ('unemployment_2009', '8.9'), ('unemployment_2014', '9.1')])
# Orignal data:
# OrderedDict([('municipality', 'Härjedalen'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Härjedalen'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Härnösand'), ('unemployment_2009', '7.9'), ('unemployment_2014', '8.9')])
# OrderedDict([('municipality', 'Härnösand'), ('unemployment_2009', '7.9'), ('unemployment_2014', '8.9')])
# Orignal data:
# OrderedDict([('municipality', 'Härryda'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.7')])
# OrderedDict([('municipality', 'Härryda'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.7')])
# Orignal data:
# OrderedDict([('municipality', 'Hässleholm'), ('unemployment_2009', '7.1'), ('unemployment_2014', '8.9')])
# OrderedDict([('municipality', 'Hässleholm'), ('unemployment_2009', '7.1'), ('unemployment_2014', '8.9')])
# Orignal data:
# OrderedDict([('municipality', 'Höganäs'), ('unemployment_2009', '4.6'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Höganäs'), ('unemployment_2009', '4.6'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Högsby'), ('unemployment_2009', '5.1'), ('unemployment_2014', '8.1')])
# OrderedDict([('municipality', 'Högsby'), ('unemployment_2009', '5.1'), ('unemployment_2014', '8.1')])
# Orignal data:
# OrderedDict([('municipality', 'Hörby'), ('unemployment_2009', '4.5'), ('unemployment_2014', '5.9')])
# OrderedDict([('municipality', 'Hörby'), ('unemployment_2009', '4.5'), ('unemployment_2014', '5.9')])
# Orignal data:
# OrderedDict([('municipality', 'Höör'), ('unemployment_2009', '4.8'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Höör'), ('unemployment_2009', '4.8'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Jokkmokk'), ('unemployment_2009', '7.1'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Jokkmokk'), ('unemployment_2009', '7.1'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Järfälla'), ('unemployment_2009', '3.6'), ('unemployment_2014', '7')])
# OrderedDict([('municipality', 'Järfälla'), ('unemployment_2009', '3.6'), ('unemployment_2014', '7')])
# Orignal data:
# OrderedDict([('municipality', 'Jönköping'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Jönköping'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Kalix'), ('unemployment_2009', '12.1'), ('unemployment_2014', '8.7')])
# OrderedDict([('municipality', 'Kalix'), ('unemployment_2009', '12.1'), ('unemployment_2014', '8.7')])
# Orignal data:
# OrderedDict([('municipality', 'Kalmar'), ('unemployment_2009', '5.7'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Kalmar'), ('unemployment_2009', '5.7'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Karlsborg'), ('unemployment_2009', '4.7'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Karlsborg'), ('unemployment_2009', '4.7'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Karlshamn'), ('unemployment_2009', '7'), ('unemployment_2014', '8.4')])
# OrderedDict([('municipality', 'Karlshamn'), ('unemployment_2009', '7'), ('unemployment_2014', '8.4')])
# Orignal data:
# OrderedDict([('municipality', 'Karlskoga'), ('unemployment_2009', '7.6'), ('unemployment_2014', '8.2')])
# OrderedDict([('municipality', 'Karlskoga'), ('unemployment_2009', '7.6'), ('unemployment_2014', '8.2')])
# Orignal data:
# OrderedDict([('municipality', 'Karlskrona'), ('unemployment_2009', '6.7'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Karlskrona'), ('unemployment_2009', '6.7'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Karlstad'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.1')])
# OrderedDict([('municipality', 'Karlstad'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.1')])
# Orignal data:
# OrderedDict([('municipality', 'Katrineholm'), ('unemployment_2009', '8'), ('unemployment_2014', '9.6')])
# OrderedDict([('municipality', 'Katrineholm'), ('unemployment_2009', '8'), ('unemployment_2014', '9.6')])
# Orignal data:
# OrderedDict([('municipality', 'Kil'), ('unemployment_2009', '7.6'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Kil'), ('unemployment_2009', '7.6'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Kinda'), ('unemployment_2009', '5.2'), ('unemployment_2014', '7.1')])
# OrderedDict([('municipality', 'Kinda'), ('unemployment_2009', '5.2'), ('unemployment_2014', '7.1')])
# Orignal data:
# OrderedDict([('municipality', 'Kiruna'), ('unemployment_2009', '6.2'), ('unemployment_2014', '3.5')])
# OrderedDict([('municipality', 'Kiruna'), ('unemployment_2009', '6.2'), ('unemployment_2014', '3.5')])
# Orignal data:
# OrderedDict([('municipality', 'Klippan'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Klippan'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Knivsta'), ('unemployment_2009', '2.7'), ('unemployment_2014', '2.9')])
# OrderedDict([('municipality', 'Knivsta'), ('unemployment_2009', '2.7'), ('unemployment_2014', '2.9')])
# Orignal data:
# OrderedDict([('municipality', 'Kramfors'), ('unemployment_2009', '9.5'), ('unemployment_2014', '10')])
# OrderedDict([('municipality', 'Kramfors'), ('unemployment_2009', '9.5'), ('unemployment_2014', '10')])
# Orignal data:
# OrderedDict([('municipality', 'Kristianstad'), ('unemployment_2009', '6.9'), ('unemployment_2014', '8.9')])
# OrderedDict([('municipality', 'Kristianstad'), ('unemployment_2009', '6.9'), ('unemployment_2014', '8.9')])
# Orignal data:
# OrderedDict([('municipality', 'Kristinehamn'), ('unemployment_2009', '8'), ('unemployment_2014', '9.7')])
# OrderedDict([('municipality', 'Kristinehamn'), ('unemployment_2009', '8'), ('unemployment_2014', '9.7')])
# Orignal data:
# OrderedDict([('municipality', 'Krokom'), ('unemployment_2009', '5.8'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Krokom'), ('unemployment_2009', '5.8'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Kumla'), ('unemployment_2009', '6.8'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Kumla'), ('unemployment_2009', '6.8'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Kungsbacka'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.4')])
# OrderedDict([('municipality', 'Kungsbacka'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.4')])
# Orignal data:
# OrderedDict([('municipality', 'Kungsör'), ('unemployment_2009', '5.2'), ('unemployment_2014', '8.7')])
# OrderedDict([('municipality', 'Kungsör'), ('unemployment_2009', '5.2'), ('unemployment_2014', '8.7')])
# Orignal data:
# OrderedDict([('municipality', 'Kungälv'), ('unemployment_2009', '3.4'), ('unemployment_2014', '2.9')])
# OrderedDict([('municipality', 'Kungälv'), ('unemployment_2009', '3.4'), ('unemployment_2014', '2.9')])
# Orignal data:
# OrderedDict([('municipality', 'Kävlinge'), ('unemployment_2009', '3.9'), ('unemployment_2014', '4.7')])
# OrderedDict([('municipality', 'Kävlinge'), ('unemployment_2009', '3.9'), ('unemployment_2014', '4.7')])
# Orignal data:
# OrderedDict([('municipality', 'Köping'), ('unemployment_2009', '7.2'), ('unemployment_2014', '8.6')])
# OrderedDict([('municipality', 'Köping'), ('unemployment_2009', '7.2'), ('unemployment_2014', '8.6')])
# Orignal data:
# OrderedDict([('municipality', 'Laholm'), ('unemployment_2009', '6'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Laholm'), ('unemployment_2009', '6'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Landskrona'), ('unemployment_2009', '8.3'), ('unemployment_2014', '11.8')])
# OrderedDict([('municipality', 'Landskrona'), ('unemployment_2009', '8.3'), ('unemployment_2014', '11.8')])
# Orignal data:
# OrderedDict([('municipality', 'Laxå'), ('unemployment_2009', '7.3'), ('unemployment_2014', '9.7')])
# OrderedDict([('municipality', 'Laxå'), ('unemployment_2009', '7.3'), ('unemployment_2014', '9.7')])
# Orignal data:
# OrderedDict([('municipality', 'Lekeberg'), ('unemployment_2009', '5.2'), ('unemployment_2014', '4.8')])
# OrderedDict([('municipality', 'Lekeberg'), ('unemployment_2009', '5.2'), ('unemployment_2014', '4.8')])
# Orignal data:
# OrderedDict([('municipality', 'Leksand'), ('unemployment_2009', '5.4'), ('unemployment_2014', '5')])
# OrderedDict([('municipality', 'Leksand'), ('unemployment_2009', '5.4'), ('unemployment_2014', '5')])
# Orignal data:
# OrderedDict([('municipality', 'Lerum'), ('unemployment_2009', '3.1'), ('unemployment_2014', '3')])
# OrderedDict([('municipality', 'Lerum'), ('unemployment_2009', '3.1'), ('unemployment_2014', '3')])
# Orignal data:
# OrderedDict([('municipality', 'Lessebo'), ('unemployment_2009', '7.7'), ('unemployment_2014', '11.7')])
# OrderedDict([('municipality', 'Lessebo'), ('unemployment_2009', '7.7'), ('unemployment_2014', '11.7')])
# Orignal data:
# OrderedDict([('municipality', 'Lidingö'), ('unemployment_2009', '1.9'), ('unemployment_2014', '3.3')])
# OrderedDict([('municipality', 'Lidingö'), ('unemployment_2009', '1.9'), ('unemployment_2014', '3.3')])
# Orignal data:
# OrderedDict([('municipality', 'Lidköping'), ('unemployment_2009', '4.8'), ('unemployment_2014', '6.6')])
# OrderedDict([('municipality', 'Lidköping'), ('unemployment_2009', '4.8'), ('unemployment_2014', '6.6')])
# Orignal data:
# OrderedDict([('municipality', 'Lilla Edet'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Lilla Edet'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Lindesberg'), ('unemployment_2009', '8.2'), ('unemployment_2014', '8.4')])
# OrderedDict([('municipality', 'Lindesberg'), ('unemployment_2009', '8.2'), ('unemployment_2014', '8.4')])
# Orignal data:
# OrderedDict([('municipality', 'Linköping'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Linköping'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Ljungby'), ('unemployment_2009', '4.8'), ('unemployment_2014', '5.6')])
# OrderedDict([('municipality', 'Ljungby'), ('unemployment_2009', '4.8'), ('unemployment_2014', '5.6')])
# Orignal data:
# OrderedDict([('municipality', 'Ljusdal'), ('unemployment_2009', '8.8'), ('unemployment_2014', '9.2')])
# OrderedDict([('municipality', 'Ljusdal'), ('unemployment_2009', '8.8'), ('unemployment_2014', '9.2')])
# Orignal data:
# OrderedDict([('municipality', 'Ljusnarsberg'), ('unemployment_2009', '7.4'), ('unemployment_2014', '10.1')])
# OrderedDict([('municipality', 'Ljusnarsberg'), ('unemployment_2009', '7.4'), ('unemployment_2014', '10.1')])
# Orignal data:
# OrderedDict([('municipality', 'Lomma'), ('unemployment_2009', '2.6'), ('unemployment_2014', '3')])
# OrderedDict([('municipality', 'Lomma'), ('unemployment_2009', '2.6'), ('unemployment_2014', '3')])
# Orignal data:
# OrderedDict([('municipality', 'Ludvika'), ('unemployment_2009', '5.6'), ('unemployment_2014', '6.6')])
# OrderedDict([('municipality', 'Ludvika'), ('unemployment_2009', '5.6'), ('unemployment_2014', '6.6')])
# Orignal data:
# OrderedDict([('municipality', 'Luleå'), ('unemployment_2009', '7.6'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Luleå'), ('unemployment_2009', '7.6'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Lund'), ('unemployment_2009', '3.5'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Lund'), ('unemployment_2009', '3.5'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Lycksele'), ('unemployment_2009', '7'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Lycksele'), ('unemployment_2009', '7'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Lysekil'), ('unemployment_2009', '5.7'), ('unemployment_2014', '4.2')])
# OrderedDict([('municipality', 'Lysekil'), ('unemployment_2009', '5.7'), ('unemployment_2014', '4.2')])
# Orignal data:
# OrderedDict([('municipality', 'Malmö'), ('unemployment_2009', '6.4'), ('unemployment_2014', '10.5')])
# OrderedDict([('municipality', 'Malmö'), ('unemployment_2009', '6.4'), ('unemployment_2014', '10.5')])
# Orignal data:
# OrderedDict([('municipality', 'Malung-Sälen'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.2')])
# OrderedDict([('municipality', 'Malung-Sälen'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.2')])
# Orignal data:
# OrderedDict([('municipality', 'Malå'), ('unemployment_2009', '7.2'), ('unemployment_2014', '6.5')])
# OrderedDict([('municipality', 'Malå'), ('unemployment_2009', '7.2'), ('unemployment_2014', '6.5')])
# Orignal data:
# OrderedDict([('municipality', 'Mariestad'), ('unemployment_2009', '7.8'), ('unemployment_2014', '8.5')])
# OrderedDict([('municipality', 'Mariestad'), ('unemployment_2009', '7.8'), ('unemployment_2014', '8.5')])
# Orignal data:
# OrderedDict([('municipality', 'Mark'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.8')])
# OrderedDict([('municipality', 'Mark'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.8')])
# Orignal data:
# OrderedDict([('municipality', 'Markaryd'), ('unemployment_2009', '5.4'), ('unemployment_2014', '7.4')])
# OrderedDict([('municipality', 'Markaryd'), ('unemployment_2009', '5.4'), ('unemployment_2014', '7.4')])
# Orignal data:
# OrderedDict([('municipality', 'Mellerud'), ('unemployment_2009', '6.2'), ('unemployment_2014', '8.1')])
# OrderedDict([('municipality', 'Mellerud'), ('unemployment_2009', '6.2'), ('unemployment_2014', '8.1')])
# Orignal data:
# OrderedDict([('municipality', 'Mjölby'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Mjölby'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Mora'), ('unemployment_2009', '6.5'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Mora'), ('unemployment_2009', '6.5'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Motala'), ('unemployment_2009', '8.1'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Motala'), ('unemployment_2009', '8.1'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Mullsjö'), ('unemployment_2009', '6.1'), ('unemployment_2014', '4.4')])
# OrderedDict([('municipality', 'Mullsjö'), ('unemployment_2009', '6.1'), ('unemployment_2014', '4.4')])
# Orignal data:
# OrderedDict([('municipality', 'Munkedal'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Munkedal'), ('unemployment_2009', '6.1'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Munkfors'), ('unemployment_2009', '10.3'), ('unemployment_2014', '9.6')])
# OrderedDict([('municipality', 'Munkfors'), ('unemployment_2009', '10.3'), ('unemployment_2014', '9.6')])
# Orignal data:
# OrderedDict([('municipality', 'Mölndal'), ('unemployment_2009', '4.3'), ('unemployment_2014', '4')])
# OrderedDict([('municipality', 'Mölndal'), ('unemployment_2009', '4.3'), ('unemployment_2014', '4')])
# Orignal data:
# OrderedDict([('municipality', 'Mönsterås'), ('unemployment_2009', '5.7'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Mönsterås'), ('unemployment_2009', '5.7'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Mörbylånga'), ('unemployment_2009', '4.7'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Mörbylånga'), ('unemployment_2009', '4.7'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Nacka'), ('unemployment_2009', '3'), ('unemployment_2014', '3.8')])
# OrderedDict([('municipality', 'Nacka'), ('unemployment_2009', '3'), ('unemployment_2014', '3.8')])
# Orignal data:
# OrderedDict([('municipality', 'Nora'), ('unemployment_2009', '7.1'), ('unemployment_2014', '6.9')])
# OrderedDict([('municipality', 'Nora'), ('unemployment_2009', '7.1'), ('unemployment_2014', '6.9')])
# Orignal data:
# OrderedDict([('municipality', 'Norberg'), ('unemployment_2009', '6.3'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Norberg'), ('unemployment_2009', '6.3'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Nordanstig'), ('unemployment_2009', '7.6'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Nordanstig'), ('unemployment_2009', '7.6'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Nordmaling'), ('unemployment_2009', '7.7'), ('unemployment_2014', '8.5')])
# OrderedDict([('municipality', 'Nordmaling'), ('unemployment_2009', '7.7'), ('unemployment_2014', '8.5')])
# Orignal data:
# OrderedDict([('municipality', 'Norrköping'), ('unemployment_2009', '8.1'), ('unemployment_2014', '10.2')])
# OrderedDict([('municipality', 'Norrköping'), ('unemployment_2009', '8.1'), ('unemployment_2014', '10.2')])
# Orignal data:
# OrderedDict([('municipality', 'Norrtälje'), ('unemployment_2009', '3'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Norrtälje'), ('unemployment_2009', '3'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Norsjö'), ('unemployment_2009', '10'), ('unemployment_2014', '8.2')])
# OrderedDict([('municipality', 'Norsjö'), ('unemployment_2009', '10'), ('unemployment_2014', '8.2')])
# Orignal data:
# OrderedDict([('municipality', 'Nybro'), ('unemployment_2009', '6.2'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Nybro'), ('unemployment_2009', '6.2'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Nykvarn'), ('unemployment_2009', '2.6'), ('unemployment_2014', '3.4')])
# OrderedDict([('municipality', 'Nykvarn'), ('unemployment_2009', '2.6'), ('unemployment_2014', '3.4')])
# Orignal data:
# OrderedDict([('municipality', 'Nyköping'), ('unemployment_2009', '6.5'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Nyköping'), ('unemployment_2009', '6.5'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Nynäshamn'), ('unemployment_2009', '4.2'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Nynäshamn'), ('unemployment_2009', '4.2'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Nässjö'), ('unemployment_2009', '6.2'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Nässjö'), ('unemployment_2009', '6.2'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Ockelbo'), ('unemployment_2009', '7.6'), ('unemployment_2014', '9.1')])
# OrderedDict([('municipality', 'Ockelbo'), ('unemployment_2009', '7.6'), ('unemployment_2014', '9.1')])
# Orignal data:
# OrderedDict([('municipality', 'Olofström'), ('unemployment_2009', '9.2'), ('unemployment_2014', '10.6')])
# OrderedDict([('municipality', 'Olofström'), ('unemployment_2009', '9.2'), ('unemployment_2014', '10.6')])
# Orignal data:
# OrderedDict([('municipality', 'Orsa'), ('unemployment_2009', '8.1'), ('unemployment_2014', '6.9')])
# OrderedDict([('municipality', 'Orsa'), ('unemployment_2009', '8.1'), ('unemployment_2014', '6.9')])
# Orignal data:
# OrderedDict([('municipality', 'Orust'), ('unemployment_2009', '4'), ('unemployment_2014', '3.9')])
# OrderedDict([('municipality', 'Orust'), ('unemployment_2009', '4'), ('unemployment_2014', '3.9')])
# Orignal data:
# OrderedDict([('municipality', 'Osby'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Osby'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Oskarshamn'), ('unemployment_2009', '3.7'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Oskarshamn'), ('unemployment_2009', '3.7'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Ovanåker'), ('unemployment_2009', '9.6'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Ovanåker'), ('unemployment_2009', '9.6'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Oxelösund'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.1')])
# OrderedDict([('municipality', 'Oxelösund'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7.1')])
# Orignal data:
# OrderedDict([('municipality', 'Pajala'), ('unemployment_2009', '12.6'), ('unemployment_2014', '6')])
# OrderedDict([('municipality', 'Pajala'), ('unemployment_2009', '12.6'), ('unemployment_2014', '6')])
# Orignal data:
# OrderedDict([('municipality', 'Partille'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Partille'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Perstorp'), ('unemployment_2009', '6.2'), ('unemployment_2014', '10.6')])
# OrderedDict([('municipality', 'Perstorp'), ('unemployment_2009', '6.2'), ('unemployment_2014', '10.6')])
# Orignal data:
# OrderedDict([('municipality', 'Piteå'), ('unemployment_2009', '7.2'), ('unemployment_2014', '6.8')])
# OrderedDict([('municipality', 'Piteå'), ('unemployment_2009', '7.2'), ('unemployment_2014', '6.8')])
# Orignal data:
# OrderedDict([('municipality', 'Ragunda'), ('unemployment_2009', '9.3'), ('unemployment_2014', '9.4')])
# OrderedDict([('municipality', 'Ragunda'), ('unemployment_2009', '9.3'), ('unemployment_2014', '9.4')])
# Orignal data:
# OrderedDict([('municipality', 'Robertsfors'), ('unemployment_2009', '7.7'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Robertsfors'), ('unemployment_2009', '7.7'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Ronneby'), ('unemployment_2009', '9.5'), ('unemployment_2014', '10.5')])
# OrderedDict([('municipality', 'Ronneby'), ('unemployment_2009', '9.5'), ('unemployment_2014', '10.5')])
# Orignal data:
# OrderedDict([('municipality', 'Rättvik'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Rättvik'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Sala'), ('unemployment_2009', '6'), ('unemployment_2014', '8')])
# OrderedDict([('municipality', 'Sala'), ('unemployment_2009', '6'), ('unemployment_2014', '8')])
# Orignal data:
# OrderedDict([('municipality', 'Salem'), ('unemployment_2009', '3.2'), ('unemployment_2014', '4.6')])
# OrderedDict([('municipality', 'Salem'), ('unemployment_2009', '3.2'), ('unemployment_2014', '4.6')])
# Orignal data:
# OrderedDict([('municipality', 'Sandviken'), ('unemployment_2009', '8.3'), ('unemployment_2014', '10.4')])
# OrderedDict([('municipality', 'Sandviken'), ('unemployment_2009', '8.3'), ('unemployment_2014', '10.4')])
# Orignal data:
# OrderedDict([('municipality', 'Sigtuna'), ('unemployment_2009', '3.8'), ('unemployment_2014', '5.4')])
# OrderedDict([('municipality', 'Sigtuna'), ('unemployment_2009', '3.8'), ('unemployment_2014', '5.4')])
# Orignal data:
# OrderedDict([('municipality', 'Simrishamn'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Simrishamn'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Sjöbo'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Sjöbo'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Skara'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Skara'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Skellefteå'), ('unemployment_2009', '8.1'), ('unemployment_2014', '7.4')])
# OrderedDict([('municipality', 'Skellefteå'), ('unemployment_2009', '8.1'), ('unemployment_2014', '7.4')])
# Orignal data:
# OrderedDict([('municipality', 'Skinnskatteberg'), ('unemployment_2009', '5.2'), ('unemployment_2014', '7')])
# OrderedDict([('municipality', 'Skinnskatteberg'), ('unemployment_2009', '5.2'), ('unemployment_2014', '7')])
# Orignal data:
# OrderedDict([('municipality', 'Skurup'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Skurup'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Skövde'), ('unemployment_2009', '6.9'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Skövde'), ('unemployment_2009', '6.9'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Smedjebacken'), ('unemployment_2009', '5.6'), ('unemployment_2014', '4.9')])
# OrderedDict([('municipality', 'Smedjebacken'), ('unemployment_2009', '5.6'), ('unemployment_2014', '4.9')])
# Orignal data:
# OrderedDict([('municipality', 'Sollefteå'), ('unemployment_2009', '9.7'), ('unemployment_2014', '11.6')])
# OrderedDict([('municipality', 'Sollefteå'), ('unemployment_2009', '9.7'), ('unemployment_2014', '11.6')])
# Orignal data:
# OrderedDict([('municipality', 'Sollentuna'), ('unemployment_2009', '3.2'), ('unemployment_2014', '4')])
# OrderedDict([('municipality', 'Sollentuna'), ('unemployment_2009', '3.2'), ('unemployment_2014', '4')])
# Orignal data:
# OrderedDict([('municipality', 'Solna'), ('unemployment_2009', '2.7'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Solna'), ('unemployment_2009', '2.7'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Sorsele'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Sorsele'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Sotenäs'), ('unemployment_2009', '3.6'), ('unemployment_2014', '4.4')])
# OrderedDict([('municipality', 'Sotenäs'), ('unemployment_2009', '3.6'), ('unemployment_2014', '4.4')])
# Orignal data:
# OrderedDict([('municipality', 'Staffanstorp'), ('unemployment_2009', '3.4'), ('unemployment_2014', '4.2')])
# OrderedDict([('municipality', 'Staffanstorp'), ('unemployment_2009', '3.4'), ('unemployment_2014', '4.2')])
# Orignal data:
# OrderedDict([('municipality', 'Stenungsund'), ('unemployment_2009', '3.8'), ('unemployment_2014', '3.6')])
# OrderedDict([('municipality', 'Stenungsund'), ('unemployment_2009', '3.8'), ('unemployment_2014', '3.6')])
# Orignal data:
# OrderedDict([('municipality', 'Stockholm'), ('unemployment_2009', '4'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Stockholm'), ('unemployment_2009', '4'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Storfors'), ('unemployment_2009', '9.1'), ('unemployment_2014', '11.5')])
# OrderedDict([('municipality', 'Storfors'), ('unemployment_2009', '9.1'), ('unemployment_2014', '11.5')])
# Orignal data:
# OrderedDict([('municipality', 'Storuman'), ('unemployment_2009', '5.8'), ('unemployment_2014', '6.3')])
# OrderedDict([('municipality', 'Storuman'), ('unemployment_2009', '5.8'), ('unemployment_2014', '6.3')])
# Orignal data:
# OrderedDict([('municipality', 'Strängnäs'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.8')])
# OrderedDict([('municipality', 'Strängnäs'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.8')])
# Orignal data:
# OrderedDict([('municipality', 'Strömstad'), ('unemployment_2009', '4.1'), ('unemployment_2014', '4.6')])
# OrderedDict([('municipality', 'Strömstad'), ('unemployment_2009', '4.1'), ('unemployment_2014', '4.6')])
# Orignal data:
# OrderedDict([('municipality', 'Strömsund'), ('unemployment_2009', '11.3'), ('unemployment_2014', '9.4')])
# OrderedDict([('municipality', 'Strömsund'), ('unemployment_2009', '11.3'), ('unemployment_2014', '9.4')])
# Orignal data:
# OrderedDict([('municipality', 'Sundbyberg'), ('unemployment_2009', '3.9'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Sundbyberg'), ('unemployment_2009', '3.9'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Sundsvall'), ('unemployment_2009', '7.2'), ('unemployment_2014', '8.1')])
# OrderedDict([('municipality', 'Sundsvall'), ('unemployment_2009', '7.2'), ('unemployment_2014', '8.1')])
# Orignal data:
# OrderedDict([('municipality', 'Sunne'), ('unemployment_2009', '7.4'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Sunne'), ('unemployment_2009', '7.4'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Surahammar'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Surahammar'), ('unemployment_2009', '6.3'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Svalöv'), ('unemployment_2009', '5'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Svalöv'), ('unemployment_2009', '5'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Svedala'), ('unemployment_2009', '3.6'), ('unemployment_2014', '4.8')])
# OrderedDict([('municipality', 'Svedala'), ('unemployment_2009', '3.6'), ('unemployment_2014', '4.8')])
# Orignal data:
# OrderedDict([('municipality', 'Svenljunga'), ('unemployment_2009', '5.6'), ('unemployment_2014', '4.4')])
# OrderedDict([('municipality', 'Svenljunga'), ('unemployment_2009', '5.6'), ('unemployment_2014', '4.4')])
# Orignal data:
# OrderedDict([('municipality', 'Säffle'), ('unemployment_2009', '7.2'), ('unemployment_2014', '10.7')])
# OrderedDict([('municipality', 'Säffle'), ('unemployment_2009', '7.2'), ('unemployment_2014', '10.7')])
# Orignal data:
# OrderedDict([('municipality', 'Säter'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.8')])
# OrderedDict([('municipality', 'Säter'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.8')])
# Orignal data:
# OrderedDict([('municipality', 'Sävsjö'), ('unemployment_2009', '6'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Sävsjö'), ('unemployment_2009', '6'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Söderhamn'), ('unemployment_2009', '9.8'), ('unemployment_2014', '10.4')])
# OrderedDict([('municipality', 'Söderhamn'), ('unemployment_2009', '9.8'), ('unemployment_2014', '10.4')])
# Orignal data:
# OrderedDict([('municipality', 'Söderköping'), ('unemployment_2009', '4.4'), ('unemployment_2014', '5.9')])
# OrderedDict([('municipality', 'Söderköping'), ('unemployment_2009', '4.4'), ('unemployment_2014', '5.9')])
# Orignal data:
# OrderedDict([('municipality', 'Södertälje'), ('unemployment_2009', '6.7'), ('unemployment_2014', '11.3')])
# OrderedDict([('municipality', 'Södertälje'), ('unemployment_2009', '6.7'), ('unemployment_2014', '11.3')])
# Orignal data:
# OrderedDict([('municipality', 'Sölvesborg'), ('unemployment_2009', '8.1'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Sölvesborg'), ('unemployment_2009', '8.1'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Tanum'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.7')])
# OrderedDict([('municipality', 'Tanum'), ('unemployment_2009', '5.5'), ('unemployment_2014', '4.7')])
# Orignal data:
# OrderedDict([('municipality', 'Tibro'), ('unemployment_2009', '8.1'), ('unemployment_2014', '8.6')])
# OrderedDict([('municipality', 'Tibro'), ('unemployment_2009', '8.1'), ('unemployment_2014', '8.6')])
# Orignal data:
# OrderedDict([('municipality', 'Tidaholm'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.3')])
# OrderedDict([('municipality', 'Tidaholm'), ('unemployment_2009', '6.6'), ('unemployment_2014', '6.3')])
# Orignal data:
# OrderedDict([('municipality', 'Tierp'), ('unemployment_2009', '6.1'), ('unemployment_2014', '7.6')])
# OrderedDict([('municipality', 'Tierp'), ('unemployment_2009', '6.1'), ('unemployment_2014', '7.6')])
# Orignal data:
# OrderedDict([('municipality', 'Timrå'), ('unemployment_2009', '8.9'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Timrå'), ('unemployment_2009', '8.9'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Tingsryd'), ('unemployment_2009', '5.3'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Tingsryd'), ('unemployment_2009', '5.3'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Tjörn'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3')])
# OrderedDict([('municipality', 'Tjörn'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3')])
# Orignal data:
# OrderedDict([('municipality', 'Tomelilla'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.6')])
# OrderedDict([('municipality', 'Tomelilla'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.6')])
# Orignal data:
# OrderedDict([('municipality', 'Torsby'), ('unemployment_2009', '6.7'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Torsby'), ('unemployment_2009', '6.7'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Torsås'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.3')])
# OrderedDict([('municipality', 'Torsås'), ('unemployment_2009', '6.4'), ('unemployment_2014', '7.3')])
# Orignal data:
# OrderedDict([('municipality', 'Tranemo'), ('unemployment_2009', '4'), ('unemployment_2014', '4.5')])
# OrderedDict([('municipality', 'Tranemo'), ('unemployment_2009', '4'), ('unemployment_2014', '4.5')])
# Orignal data:
# OrderedDict([('municipality', 'Tranås'), ('unemployment_2009', '4.7'), ('unemployment_2014', '7.4')])
# OrderedDict([('municipality', 'Tranås'), ('unemployment_2009', '4.7'), ('unemployment_2014', '7.4')])
# Orignal data:
# OrderedDict([('municipality', 'Trelleborg'), ('unemployment_2009', '6'), ('unemployment_2014', '7.9')])
# OrderedDict([('municipality', 'Trelleborg'), ('unemployment_2009', '6'), ('unemployment_2014', '7.9')])
# Orignal data:
# OrderedDict([('municipality', 'Trollhättan'), ('unemployment_2009', '8.6'), ('unemployment_2014', '11.5')])
# OrderedDict([('municipality', 'Trollhättan'), ('unemployment_2009', '8.6'), ('unemployment_2014', '11.5')])
# Orignal data:
# OrderedDict([('municipality', 'Trosa'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Trosa'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Tyresö'), ('unemployment_2009', '2.8'), ('unemployment_2014', '3.5')])
# OrderedDict([('municipality', 'Tyresö'), ('unemployment_2009', '2.8'), ('unemployment_2014', '3.5')])
# Orignal data:
# OrderedDict([('municipality', 'Täby'), ('unemployment_2009', '1.8'), ('unemployment_2014', '2.4')])
# OrderedDict([('municipality', 'Täby'), ('unemployment_2009', '1.8'), ('unemployment_2014', '2.4')])
# Orignal data:
# OrderedDict([('municipality', 'Töreboda'), ('unemployment_2009', '8.2'), ('unemployment_2014', '9')])
# OrderedDict([('municipality', 'Töreboda'), ('unemployment_2009', '8.2'), ('unemployment_2014', '9')])
# Orignal data:
# OrderedDict([('municipality', 'Uddevalla'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Uddevalla'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Ulricehamn'), ('unemployment_2009', '5'), ('unemployment_2014', '4.5')])
# OrderedDict([('municipality', 'Ulricehamn'), ('unemployment_2009', '5'), ('unemployment_2014', '4.5')])
# Orignal data:
# OrderedDict([('municipality', 'Umeå'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.3')])
# OrderedDict([('municipality', 'Umeå'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.3')])
# Orignal data:
# OrderedDict([('municipality', 'Upplands Väsby'), ('unemployment_2009', '3.8'), ('unemployment_2014', '5.1')])
# OrderedDict([('municipality', 'Upplands Väsby'), ('unemployment_2009', '3.8'), ('unemployment_2014', '5.1')])
# Orignal data:
# OrderedDict([('municipality', 'Upplands-Bro'), ('unemployment_2009', '3.9'), ('unemployment_2014', '6.1')])
# OrderedDict([('municipality', 'Upplands-Bro'), ('unemployment_2009', '3.9'), ('unemployment_2014', '6.1')])
# Orignal data:
# OrderedDict([('municipality', 'Uppsala'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Uppsala'), ('unemployment_2009', '3.7'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Uppvidinge'), ('unemployment_2009', '6.8'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Uppvidinge'), ('unemployment_2009', '6.8'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Vadstena'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6')])
# OrderedDict([('municipality', 'Vadstena'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6')])
# Orignal data:
# OrderedDict([('municipality', 'Vaggeryd'), ('unemployment_2009', '6.4'), ('unemployment_2014', '6.3')])
# OrderedDict([('municipality', 'Vaggeryd'), ('unemployment_2009', '6.4'), ('unemployment_2014', '6.3')])
# Orignal data:
# OrderedDict([('municipality', 'Valdemarsvik'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.4')])
# OrderedDict([('municipality', 'Valdemarsvik'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.4')])
# Orignal data:
# OrderedDict([('municipality', 'Vallentuna'), ('unemployment_2009', '1.7'), ('unemployment_2014', '2.2')])
# OrderedDict([('municipality', 'Vallentuna'), ('unemployment_2009', '1.7'), ('unemployment_2014', '2.2')])
# Orignal data:
# OrderedDict([('municipality', 'Vansbro'), ('unemployment_2009', '6.9'), ('unemployment_2014', '5.9')])
# OrderedDict([('municipality', 'Vansbro'), ('unemployment_2009', '6.9'), ('unemployment_2014', '5.9')])
# Orignal data:
# OrderedDict([('municipality', 'Vara'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.3')])
# OrderedDict([('municipality', 'Vara'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.3')])
# Orignal data:
# OrderedDict([('municipality', 'Varberg'), ('unemployment_2009', '4'), ('unemployment_2014', '4.1')])
# OrderedDict([('municipality', 'Varberg'), ('unemployment_2009', '4'), ('unemployment_2014', '4.1')])
# Orignal data:
# OrderedDict([('municipality', 'Vaxholm'), ('unemployment_2009', '1.5'), ('unemployment_2014', '2.2')])
# OrderedDict([('municipality', 'Vaxholm'), ('unemployment_2009', '1.5'), ('unemployment_2014', '2.2')])
# Orignal data:
# OrderedDict([('municipality', 'Vellinge'), ('unemployment_2009', '2.8'), ('unemployment_2014', '4')])
# OrderedDict([('municipality', 'Vellinge'), ('unemployment_2009', '2.8'), ('unemployment_2014', '4')])
# Orignal data:
# OrderedDict([('municipality', 'Vetlanda'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.5')])
# OrderedDict([('municipality', 'Vetlanda'), ('unemployment_2009', '5.5'), ('unemployment_2014', '5.5')])
# Orignal data:
# OrderedDict([('municipality', 'Vilhelmina'), ('unemployment_2009', '8.8'), ('unemployment_2014', '10.8')])
# OrderedDict([('municipality', 'Vilhelmina'), ('unemployment_2009', '8.8'), ('unemployment_2014', '10.8')])
# Orignal data:
# OrderedDict([('municipality', 'Vimmerby'), ('unemployment_2009', '7'), ('unemployment_2014', '5.8')])
# OrderedDict([('municipality', 'Vimmerby'), ('unemployment_2009', '7'), ('unemployment_2014', '5.8')])
# Orignal data:
# OrderedDict([('municipality', 'Vindeln'), ('unemployment_2009', '7.5'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Vindeln'), ('unemployment_2009', '7.5'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Vingåker'), ('unemployment_2009', '6.3'), ('unemployment_2014', '9.6')])
# OrderedDict([('municipality', 'Vingåker'), ('unemployment_2009', '6.3'), ('unemployment_2014', '9.6')])
# Orignal data:
# OrderedDict([('municipality', 'Vårgårda'), ('unemployment_2009', '6'), ('unemployment_2014', '5.7')])
# OrderedDict([('municipality', 'Vårgårda'), ('unemployment_2009', '6'), ('unemployment_2014', '5.7')])
# Orignal data:
# OrderedDict([('municipality', 'Vänersborg'), ('unemployment_2009', '6.5'), ('unemployment_2014', '8.5')])
# OrderedDict([('municipality', 'Vänersborg'), ('unemployment_2009', '6.5'), ('unemployment_2014', '8.5')])
# Orignal data:
# OrderedDict([('municipality', 'Vännäs'), ('unemployment_2009', '4.4'), ('unemployment_2014', '6')])
# OrderedDict([('municipality', 'Vännäs'), ('unemployment_2009', '4.4'), ('unemployment_2014', '6')])
# Orignal data:
# OrderedDict([('municipality', 'Värmdö'), ('unemployment_2009', '2.7'), ('unemployment_2014', '3.5')])
# OrderedDict([('municipality', 'Värmdö'), ('unemployment_2009', '2.7'), ('unemployment_2014', '3.5')])
# Orignal data:
# OrderedDict([('municipality', 'Värnamo'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.6')])
# OrderedDict([('municipality', 'Värnamo'), ('unemployment_2009', '5.7'), ('unemployment_2014', '5.6')])
# Orignal data:
# OrderedDict([('municipality', 'Västervik'), ('unemployment_2009', '7.1'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Västervik'), ('unemployment_2009', '7.1'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Västerås'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.6')])
# OrderedDict([('municipality', 'Västerås'), ('unemployment_2009', '6.7'), ('unemployment_2014', '7.6')])
# Orignal data:
# OrderedDict([('municipality', 'Växjö'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Växjö'), ('unemployment_2009', '5.9'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Ydre'), ('unemployment_2009', '4.8'), ('unemployment_2014', '3.6')])
# OrderedDict([('municipality', 'Ydre'), ('unemployment_2009', '4.8'), ('unemployment_2014', '3.6')])
# Orignal data:
# OrderedDict([('municipality', 'Ystad'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.6')])
# OrderedDict([('municipality', 'Ystad'), ('unemployment_2009', '5.3'), ('unemployment_2014', '5.6')])
# Orignal data:
# OrderedDict([('municipality', 'Åmål'), ('unemployment_2009', '9.4'), ('unemployment_2014', '10')])
# OrderedDict([('municipality', 'Åmål'), ('unemployment_2009', '9.4'), ('unemployment_2014', '10')])
# Orignal data:
# OrderedDict([('municipality', 'Ånge'), ('unemployment_2009', '8.1'), ('unemployment_2014', '9.5')])
# OrderedDict([('municipality', 'Ånge'), ('unemployment_2009', '8.1'), ('unemployment_2014', '9.5')])
# Orignal data:
# OrderedDict([('municipality', 'Åre'), ('unemployment_2009', '4.1'), ('unemployment_2014', '4.4')])
# OrderedDict([('municipality', 'Åre'), ('unemployment_2009', '4.1'), ('unemployment_2014', '4.4')])
# Orignal data:
# OrderedDict([('municipality', 'Årjäng'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.2')])
# OrderedDict([('municipality', 'Årjäng'), ('unemployment_2009', '5.2'), ('unemployment_2014', '6.2')])
# Orignal data:
# OrderedDict([('municipality', 'Åsele'), ('unemployment_2009', '9.2'), ('unemployment_2014', '8.3')])
# OrderedDict([('municipality', 'Åsele'), ('unemployment_2009', '9.2'), ('unemployment_2014', '8.3')])
# Orignal data:
# OrderedDict([('municipality', 'Åstorp'), ('unemployment_2009', '7.6'), ('unemployment_2014', '8.4')])
# OrderedDict([('municipality', 'Åstorp'), ('unemployment_2009', '7.6'), ('unemployment_2014', '8.4')])
# Orignal data:
# OrderedDict([('municipality', 'Åtvidaberg'), ('unemployment_2009', '7.8'), ('unemployment_2014', '6.4')])
# OrderedDict([('municipality', 'Åtvidaberg'), ('unemployment_2009', '7.8'), ('unemployment_2014', '6.4')])
# Orignal data:
# OrderedDict([('municipality', 'Älmhult'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.9')])
# OrderedDict([('municipality', 'Älmhult'), ('unemployment_2009', '4.5'), ('unemployment_2014', '4.9')])
# Orignal data:
# OrderedDict([('municipality', 'Älvdalen'), ('unemployment_2009', '7.3'), ('unemployment_2014', '6.6')])
# OrderedDict([('municipality', 'Älvdalen'), ('unemployment_2009', '7.3'), ('unemployment_2014', '6.6')])
# Orignal data:
# OrderedDict([('municipality', 'Älvkarleby'), ('unemployment_2009', '6.8'), ('unemployment_2014', '9.4')])
# OrderedDict([('municipality', 'Älvkarleby'), ('unemployment_2009', '6.8'), ('unemployment_2014', '9.4')])
# Orignal data:
# OrderedDict([('municipality', 'Älvsbyn'), ('unemployment_2009', '8.9'), ('unemployment_2014', '7.9')])
# OrderedDict([('municipality', 'Älvsbyn'), ('unemployment_2009', '8.9'), ('unemployment_2014', '7.9')])
# Orignal data:
# OrderedDict([('municipality', 'Ängelholm'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.3')])
# OrderedDict([('municipality', 'Ängelholm'), ('unemployment_2009', '5.5'), ('unemployment_2014', '6.3')])
# Orignal data:
# OrderedDict([('municipality', 'Öckerö'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.2')])
# OrderedDict([('municipality', 'Öckerö'), ('unemployment_2009', '3.3'), ('unemployment_2014', '3.2')])
# Orignal data:
# OrderedDict([('municipality', 'Ödeshög'), ('unemployment_2009', '6.9'), ('unemployment_2014', '6.7')])
# OrderedDict([('municipality', 'Ödeshög'), ('unemployment_2009', '6.9'), ('unemployment_2014', '6.7')])
# Orignal data:
# OrderedDict([('municipality', 'Örebro'), ('unemployment_2009', '6.9'), ('unemployment_2014', '7.2')])
# OrderedDict([('municipality', 'Örebro'), ('unemployment_2009', '6.9'), ('unemployment_2014', '7.2')])
# Orignal data:
# OrderedDict([('municipality', 'Örkelljunga'), ('unemployment_2009', '4.9'), ('unemployment_2014', '7.5')])
# OrderedDict([('municipality', 'Örkelljunga'), ('unemployment_2009', '4.9'), ('unemployment_2014', '7.5')])
# Orignal data:
# OrderedDict([('municipality', 'Örnsköldsvik'), ('unemployment_2009', '7.2'), ('unemployment_2014', '7.8')])
# OrderedDict([('municipality', 'Örnsköldsvik'), ('unemployment_2009', '7.2'), ('unemployment_2014', '7.8')])
# Orignal data:
# OrderedDict([('municipality', 'Östersund'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7')])
# OrderedDict([('municipality', 'Östersund'), ('unemployment_2009', '6.5'), ('unemployment_2014', '7')])
# Orignal data:
# OrderedDict([('municipality', 'Österåker'), ('unemployment_2009', '2.1'), ('unemployment_2014', '3')])
# OrderedDict([('municipality', 'Österåker'), ('unemployment_2009', '2.1'), ('unemployment_2014', '3')])
# Orignal data:
# OrderedDict([('municipality', 'Östhammar'), ('unemployment_2009', '3'), ('unemployment_2014', '4.2')])
# OrderedDict([('municipality', 'Östhammar'), ('unemployment_2009', '3'), ('unemployment_2014', '4.2')])
# Orignal data:
# OrderedDict([('municipality', 'Östra Göinge'), ('unemployment_2009', '8.3'), ('unemployment_2014', '9.9')])
# OrderedDict([('municipality', 'Östra Göinge'), ('unemployment_2009', '8.3'), ('unemployment_2014', '9.9')])
# Orignal data:
# OrderedDict([('municipality', 'Överkalix'), ('unemployment_2009', '13'), ('unemployment_2014', '10')])
# OrderedDict([('municipality', 'Överkalix'), ('unemployment_2009', '13'), ('unemployment_2014', '10')])
# Orignal data:
# OrderedDict([('municipality', 'Övertorneå'), ('unemployment_2009', '13'), ('unemployment_2014', '9.3')])
# OrderedDict([('municipality', 'Övertorneå'), ('unemployment_2009', '13'), ('unemployment_2014', '9.3')])

# %%
a = '4.4'
a = float(a)
print(a * 2)
# Out:
# 8.8
