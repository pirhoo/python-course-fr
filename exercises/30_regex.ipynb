# %%
# %load 30_regex.py

from urllib import request
import re
import time
# Si BeautifulSoup n'est pas installé: pip install beautifulsoup4
from bs4 import BeautifulSoup

base = "https://www.leboncoin.fr/_loisirs_/offres/ile_de_france/?th=1&q=v%E9lo&o="
ads = []

def clean(string):
    return string.strip().replace('\n', ' ').replace('\r', ' ')

def save_ad(soup):
    # On stock plusieurs valeurs dans un dictionaire nommé "values" et on ajoute
    values = {
        'title':       clean(soup.select('h1')[0].text),
        'description': clean(soup.select('.properties_description')[0].text),
        'price':       clean(soup.select('.item_price .value')[0].text),
        'city':        clean(soup.select('.line_city .value')[0].text)
    }
    # On a ajoute cette annonce à la liste des annonces à sauvegarder
    ads.append(values)

def fetch_ad(url):
    time.sleep(3.3)
    # On ouvre l'autre URL et on stock le resultat dans body
    body = request.urlopen(url).read()
    # Parse le HTML avec Beautiful Soup
    save_ad( BeautifulSoup(body, 'html.parser') )

def fetch_list(page = 1):
    # On ouvre l'autre URL et on stock le resultat dans body
    body = request.urlopen(base + str(page)).read()
    # Parse le HTML avec Beautiful Soup
    soup = BeautifulSoup(body, 'html.parser')
    # Tous les éléments de la liste
    for list_item in soup.select(".list_item"):
        # Seulement les annonces avec un prix
        if list_item.section.h3 != None:
            url = list_item['href']
            # L'URL sur Le Bon Coin ne contient pas le protocol
            url = url if url.startswith("http") else "http:%s" % url
            # On affiche dans la console la procédure en cours
            print(u"Téléchargement de %s" % url)
            # On appelle ici l'autre fonction pour télécharger une annonce
            fetch_ad(url)

# Toutes les annonces de la page 1 sont stockées dans la liste "ads"
fetch_list(1)
# Parcours la liste des annonces
for ad in ads:
    # Trouve toute les occurences de la regex pour trouver un numéro de téléphone
    matches = re.search('0[1-9]{1}( |\.)?[0-9]{2}( |\.)?[0-9]{2}( |\.)?[0-9]{2}( |\.)?[0-9]{2}', ad['description'])
    # Si matches n'est pas None, ça veut dire qu'on a trouvé des occurences
    if matches is not None:
        print(matches.group(0))
# Out:
# Téléchargement de http://www.leboncoin.fr/velos/1354786729.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354786261.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/795184801.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1354785099.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354763166.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354784322.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354783302.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/1354782751.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354782551.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354782498.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354781674.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354781123.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354780336.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354779411.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354779250.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354778909.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1320175112.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1319437558.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354776450.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354775973.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354775265.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1320120447.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/899438111.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354773638.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354751806.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354773092.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1354773048.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1354772540.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1122765070.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1122760885.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1122766392.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1066922466.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354770523.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354770518.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354770407.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354770304.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354768091.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354768101.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354768038.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354766524.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1337286221.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354764426.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354763682.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354763073.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/1352760238.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/1123304243.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/1352761152.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354762645.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1352762112.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1327023925.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354762471.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1352762963.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1354761262.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/collection/1354760869.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354760498.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354603768.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354759297.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1320513309.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354758822.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1347258863.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354756668.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354756473.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/jeux_jouets/1354755360.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/velos/1354755263.htm?ca=12_s
# Téléchargement de http://www.leboncoin.fr/sports_hobbies/1354755142.htm?ca=12_s
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-11-dadbfabe3d7b> in <module>()
#      50 # Toutes les annonces de la page 1 sont stockées dans la liste "ads"
#      51 fetch_list(1)
# ---> 52 fetch_list(2)
#      53 # Parcours la liste des annonces
#      54 for ad in ads:
#
# <ipython-input-11-dadbfabe3d7b> in fetch_list(page)
#      46             print(u"Téléchargement de %s" % url)
#      47             # On appelle ici l'autre fonction pour télécharger une annonce
# ---> 48             fetch_ad(url)
#      49
#      50 # Toutes les annonces de la page 1 sont stockées dans la liste "ads"
#
# <ipython-input-11-dadbfabe3d7b> in fetch_ad(url)
#      27     time.sleep(3.3)
#      28     # On ouvre l'autre URL et on stock le resultat dans body
# ---> 29     body = request.urlopen(url).read()
#      30     # Parse le HTML avec Beautiful Soup
#      31     save_ad( BeautifulSoup(body, 'html.parser') )
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/.anaconda/3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 408: Request Time-out
